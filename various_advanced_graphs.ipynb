# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib import rc
df = pd.read_csv("C:\\Users\\UMANG PATEL\\Desktop\\Combine_Data.csv")
df.head()
# Out:
#         BillNo  BillQty           BillParty    BillDate  BillProdNo  \
# 0  E1617-75852    10.00                 NaN  2019-01-16           2
# 1  E1617-75852     6.00                 NaN  2019-01-16           1
# 2  E1617-75853     3.00  HAREKRISHNA BAKERY  2019-01-16           1
# 3  E1617-75854     0.25                 NaN  2019-01-16           1
# 4  E1617-75855     3.00                 NaN  2019-01-16           1
#
#   BillProdCode    BillProdName  BillAddTax  BillRate  BillVat  BillAmt  \
# 0        BAT01          BATAKA           0      14.0      0.0    140.0
# 1        DUN01          DUNGRI           0      12.0      0.0     72.0
# 2        RIN07  RINGAN BHARTHA           0      38.0      0.0    114.0
# 3        GAJ01           GAJAR           0      24.0      0.0      6.0
# 4        BAN01          BANANA           0       3.4      0.0     10.2
#
#    BillFree BillPartyType ProdCategory  ProdPRate  ProdSRate  month  year  \
# ...

# %%
Quntity=(df.BillQty.head())
Rate = (df.iloc[:5,12])
Amount = (df.iloc[:5,14])
# ProdName = [5,10,15,20,25]
Prodname = (df.iloc[:5,6])
index = np.arange(len(Rate))

# %%
# plt.plot([],[],color='m',label='Rate',linewidth=5)
plt.stackplot(ProdName,Quntity,Rate,Amount,colors=['m','c','r'])
plt.legend(('Quntity','Rate','Amount'))
# plt.legend()

# %%
plt.bar(x=index,height=Quntity,width=0.30)
plt.bar(x=index,height=Amount,width=0.30,bottom=Quntity)
plt.bar(x=index,height=Rate,width=0.30,bottom=Quntity+Amount)

plt.xlabel('ProdName')
plt.ylabel('Values')
plt.xticks(index,Prodname)
plt.yticks(np.arange(0,200,200/len(index)))
plt.title('Rate,Amount and Qunity of first 5 products')
plt.legend(('Quntity','Amount','Rate'))
plt.figure(figsize=(10,7))

plt.show()

# %%
df2 = df.loc[:4,['BillQty','BillAmt','BillRate']]
df3 = df.loc[5:9,['BillQty','BillAmt','BillRate']]

# %%
df2.plot(kind='bar',stacked=True,width=0.30)

# %%
import numpy as np
import matplotlib.pyplot as plt

#Note the parameters yerr used for error bars

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()
fig
# plt.show()

# %%
# The function returns a figure object and a tuple containing axes objects equal to nrows*ncols. Each axes object is 
# accessible by its index. Here we create a subplot of 2 rows by 2 columns and display 4 different plots in each subplot

import matplotlib.pyplot as plt
fig,a =  plt.subplots(2,2)
import numpy as np
x = np.arange(1,5)
a[0][0].plot(x,x*x)
a[0][0].set_title('square')
a[0][1].plot(x,np.sqrt(x))
a[0][1].set_title('square root')
a[1][0].plot(x,np.exp(x))
a[1][0].set_title('exp')
a[1][1].plot(x,np.log10(x))
a[1][1].set_title('log')
plt.show()

# %%
# The heatmap itself is an imshow plot with the labels set to the categories we have.
# Finally we can label the data itself by creating a Text within each cell showing the value of that cell.
# Xarray-like or PIL image
# The image data. Supported array shapes are:
# axes.imshow(self,X)
# (M, N): an image with scalar data. The values are mapped to colors using normalization and a colormap. See parameters norm, cmap, vmin, vmax.
# (M, N, 3): an image with RGB values (0-1 float or 0-255 int).
# (M, N, 4): an image with RGBA values (0-1 float or 0-255 int), i.e. including transparency.
# The first two dimensions (M, N) define the rows and columns of the image.
# Out-of-range RGB(A) values are clipped.

# sphinx_gallery_thumbnail_number = 2

vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


fig, ax = plt.subplots()
im = ax.imshow((harvest))           #colormap accoridng to value

# We want to show all ticks...
ax.set_xticks(np.arange(len(farmers)))
ax.set_yticks(np.arange(len(vegetables)))
# ... and label them with the respective list entries
ax.set_xticklabels(farmers)
ax.set_yticklabels(vegetables)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j, i, harvest[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.show()

# %%
np.random.seed(19680801)

n_bins = 10
x = np.random.randn(1000, 3)

fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(nrows=2, ncols=2)

colors = ['red', 'tan', 'lime']
ax0.hist(x, n_bins, density=True, histtype='bar', color=colors, label=colors)
ax0.legend(prop={'size': 10})
ax0.set_title('bars with legend')

ax1.hist(x, n_bins, density=True, histtype='bar', stacked=True)
ax1.set_title('stacked bar')

ax2.hist(x, n_bins, histtype='step', stacked=True, fill=False)
ax2.set_title('stack step (unfilled)')

# Make a multiple-histogram of data-sets with different length.
x_multi = [np.random.randn(n) for n in [10000, 5000, 2000]]
ax3.hist(x_multi, n_bins, histtype='bar')
ax3.set_title('different sample sizes')
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 3), )

recipe = ["375 g flour",
          "75 g sugar",
          "250 g butter",
          "300 g berries"]

# data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]

print(data)
print(ingredients)
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Matplotlib bakery: A pie")

plt.show()
# Out:
# [375.0, 75.0, 250.0, 300.0]
# ['flour', 'sugar', 'butter', 'berries']

# %%
# Data
df = pd.read_csv("C:\\Users\\UMANG PATEL\\Desktop\\Combine_Data.csv")
 
fig = plt.figure(figsize=(8,5))


ProdPRate = df.iloc[:5,14]
Rate = (df.iloc[:5,8])
Amount = (df.iloc[:5,10])
Prodname = (df.iloc[:5,6])
index = np.arange(len(Rate))

for i in df.index:
    df.loc[i]=df.loc[i]*100/sum(df.loc[i])


btm = 0
labels=['PROD_PURCHASE_RATE','AMOUNT','RATE'] # If the original column order is fine, skip it
colors=['green','orange','blue']

    
for i,j in zip(labels,colors): # If the original column order is fine, just replace “stack_order” for “df”
    plt.bar(r,df[i],bottom=btm,color=j,label=i)
    btm=btm+df[i]
    


# totals = [i+j+k for i,j,k in zip(ProdPRate, Rate, Amount)]
# ProdPRate = [i / j * 100 for i,j in zip(ProdPRate, totals)]
# Amount = [i / j * 100 for i,j in zip(Amount, totals)]
# Rate  = [i / j * 100 for i,j in zip(Rate, totals)]
# barWidth = 0.85
# plt.bar(index, ProdPRate, color='#b5ffb9', width=barWidth, edgecolor='white', label='PROD_PURCHASE_RATE')
# plt.bar(index, Amount, bottom=ProdPRate, color='#f9bc86', edgecolor='white', width=barWidth, label='AMOUNT')
# plt.bar(index, Rate, bottom=[i+j for i,j in zip(ProdPRate, Amount)], color='#a3acff', edgecolor='white', width=barWidth, label='RATE')
# plt.xticks(index, Prodname)
# plt.xlabel("ProdName")
# plt.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)
# plt.show()
# Out:
#   File "<ipython-input-25-76b61ae6d97d>", line 18
#     labels=['PROD_PURCHASE_RATE','AMOUNT',label='RATE'] # If the original column order is fine, skip it
#                                                ^
# SyntaxError: invalid syntax

# %%
df.head()
# Out:
# BillNo           E1617-75852
# BillQty                    6
# BillParty                NaN
# BillDate          2019-01-16
# BillProdNo                 1
# BillProdCode           DUN01
# BillProdName          DUNGRI
# BillAddTax                 0
# BillRate                  12
# BillVat                    0
# BillAmt                   72
# BillFree                   0
# BillPartyType              R
# ProdCategory       Vegetable
# ProdPRate                 10
# ProdSRate                 16
# month                      1
# year                    2019
# weekday            Wednesday
# Name: 1, dtype: object

# %%
# Data
# names = [“A”,”B”,”C”,”D”,”E”]
names = ['a','b','c','d','e']
raw_data = {'greenBars': [20, 1.5, 7, 10, 5], 'orangeBars': [5, 15, 5, 10, 15],'blueBars': [2, 15, 18, 5, 10]}
df = pd.DataFrame(raw_data,index=names)

# Get the %
for i in df.index:
    df.loc[i]=df.loc[i]*100/sum(df.loc[i])

# Plotting
r=range(len(names))
# btm=df.iloc[:,0]-df.iloc[:,0] # Looks horrible, I know, enjoy it
btm = 0
stack_order=['greenBars','orangeBars','blueBars'] # If the original column order is fine, skip it
colors=['green','orange','blue']

for i,j in zip(stack_order,colors): # If the original column order is fine, just replace “stack_order” for “df”
    plt.bar(r,df[i],bottom=btm,color=j,label=i)
    btm=btm+df[i]

plt.legend(loc=1)
plt.xticks(r, names)
plt.xlabel('Group')
plt.ylabel('Percentage')
plt.show()
